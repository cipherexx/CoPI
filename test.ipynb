# %%
from gnews import GNews
news=GNews()

# %%
response=news.get_news("swiggy")
print(response)
# Out:
# [{'title': 'Swiggy Q4 FY25 Adjusted EBITDA Loss Increased to INR 840 Crore - MSN', 'description': 'Swiggy Q4 FY25 Adjusted EBITDA Loss Increased to INR 840 Crore  MSN', 'published date': 'Sat, 10 May 2025 11:17:36 GMT', 'url': 'https://news.google.?oc=5&hl=en-IN&gl=IN&ceid=IN:en', 'publisher': {'href': 'https://www.msn.com', 'title': 'MSN'}}, {'title': 'Swiggy Launches Mother’s Day Film Exploring Grief, Memory, and Healing - Branding in Asia', 'description': 'Swiggy Launches Mother’s Day Film Exploring Grief, Memory, and Healing  Branding in Asia', 'published date': 'Sat, 10 May 2025 11:03:11 GMT', 'url': 'https://news.google.com/rss/articles/CBMioAFBVV95cUxPeGZ1R2NZTFdkRnR0RFlfdm00ej
# ...

# %%
print(type(response))
# Out:
# <class 'list'>

# %%
import json
with open("news.json","w") as f:
    json.dump(response, f, indent=2)
